# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

# %%
x = np.arange(0.0, 600.0, 0.5)
y = 1/(10**(-x/400) + 1)

# %%
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,...">

# %%
x = np.arange(0.0, 600.0, 0.5)
y1 = 1/(10**(-100.0/400.0) + 1)
y2 = 1/(10**(-165.0/400.0) + 1)

# %%
y2 - y1
# Out:
# 0.08101324339467497

# %%
1/(10**(-(1560-1426)/400.0) + 1)
# Out:
# 0.6838163141936586
